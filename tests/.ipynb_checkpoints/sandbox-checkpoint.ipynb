# %% [markdown]
# # 1. Data Preprocessing

# %%
import numpy as np
import os
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torch_geometric.data import Data
from torch_geometric.nn import GATConv

# %%
# Import data

def import_data(dir, norm=True):
    dfs = []
    min_val,max_val = (None,None)
    for file in os.listdir(dir):
        df = pd.read_csv(f"{os.path.join(dir,file)}", sep="\t", header=None)    
        dfs.append(df)
        min_val = min(df.values.min(), min_val) if min_val else df.values.min()
        max_val = max(df.values.max(), max_val) if max_val else df.values.max()
    '''for i,df in enumerate(dfs):
        dfs[i] = (df-min_val)/(max_val-min_val)'''
        
    return dfs, min_val, max_val

train_dfs, train_min, train_max = import_data("/Users/faith/Desktop/Projects/tsad/data/train")
test_dfs, test_min, test_max = import_data("/Users/faith/Desktop/Projects/tsad/data/test")

# %%
# Convert to Tensors

train = torch.FloatTensor(train_dfs[0].values)
test = torch.FloatTensor(test_dfs[0].values)

# %%
# Assign time windows + target

def reshape_tensor(df, time_window):
    n,k = df.shape
    num_windows = n//time_window
    return df[:num_windows*time_window].reshape([num_windows, time_window,k])


def get_targets(df, time_window):
    n,k = df.shape
    idxs = np.arange(time_window,n,time_window)+1
    return df[idxs]

time_window = 100
train_windows = reshape_tensor(train,time_window)[:-1] # delete last window (no label)
train_targets = get_targets(train,time_window)

# %%
train.shape, train_windows.shape
# Out:
# (torch.Size([86400, 33]), torch.Size([863, 100, 33]))

# %%
# Create Dataset Class

class TimewindowDataset(Dataset):
    def __init__(self, windows, window_labels):
        self.windows = windows
        self.window_labels = window_labels
        
    def __len__(self):
        return self.windows.shape[0]
    
    def __getitem__(self,i):
        return self.windows[i], self.window_labels[i]
    
train_dataset = TimewindowDataset(train_windows, train_targets)
train_dataloader = DataLoader(train_dataset)

# %% [markdown]
# # 2. Model

# %%
# 1D Conv + 2 GATs + GRU + FFN

class GATModel(torch.nn.Module):
    def __init__(self, n, k, kernel_size=3, hidden_dim=256, n_layers=1):
        """
        n = number timesteps
        k = number sensors
        """
        super().__init__()
               
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers
        self.conv1 = nn.Conv1d(k, k, kernel_size)
        self.feature_conv1 = GATConv(n-kernel_size+1, n-kernel_size+1)
        self.time_conv1 = GATConv(k, k, dropout=0.05)
        #self.gru = nn.GRU((n-kernel_size+1)*3, hidden_dim, n_layers, batch_first=True, dropout=0.1)
        self.gru = nn.GRU(k*3, k*4, n_layers, batch_first=True)
        self.fc1 = nn.Linear(n, k*4)
        self.fc2 = nn.Linear(k*4, k*4)
        self.fc3 = nn.Linear(k*4, k*4)
        self.fc4 = nn.Linear(k*4, k)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        
    def forward(self,x,h):
        # 1. Sensor-wise Convolution
        '''x = self.sensor_conv(x)
        # 2. Parallel GAT
        x1 = self.feature_gat(x)
        x2 = self.time_gat(x)
        # 3. Concat x, x1, x2
        x = self.concat(x,x1,x2)
        # 4. GRU
        x,h = self.gru(x,h)'''
        # 5. Forecasting Model
        #x = torch.flatten(x)
        x = self.fc1(x.T)
        x = self.sigmoid(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        x = self.fc3(x)
        x = self.sigmoid(x)
        x = self.fc4(x)
        
        # 6. Reconstruction Model
        
        return x,h
    
    def init_hidden(self,batch_size):
        return torch.zeros(self.n_layers,k*4)#self.hidden_dim)
        
    def sensor_conv(self,x):
        """
        For each sensor, do a 1D convolution of kernel size 7.
        input: nxk
        output: kxn
        """
        return self.conv1(x.T)
    
    def complete_edge_idx(self, num_nodes):
        nodes = torch.tensor(list(range(num_nodes)))
        idx1 = nodes.repeat_interleave(num_nodes)
        idx2 = nodes.repeat(num_nodes)
        return torch.vstack((idx1,idx2))
        
    def feature_gat(self,x):
        """
        1 node for each sensor
        input: kxn
        output: kxn
        """
        edge_idx = self.complete_edge_idx(x.shape[0])
        data = Data(x=x, edge_index=edge_idx)
        x = self.feature_conv1(data.x, data.edge_index)
        return x
    
    def time_gat(self,x):
        """
        1 node for each timestep
        input: kxn
        output: nxk
        """
        x = x.T 
        edge_idx = self.complete_edge_idx(x.shape[0])
        data = Data(x=x, edge_index=edge_idx)
        x = self.time_conv1(data.x, data.edge_index)
        return x
    
    def concat(self,x,x1,x2):
        """
        Concatenate x, x1, x2
        input: kxn, kxn, nxk
        output: nx3k
        """
        return torch.hstack((x.T,x1.T,x2))

# %% [markdown]
# # 3. Training

# %%
num_windows,n,k = train_windows.shape
learn_rate=1e-3
EPOCHS = 200
model = GATModel(n,k)
h = model.init_hidden(1)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)
for epoch in range(0,EPOCHS):
    for i,item in enumerate(train_dataloader):
        window, target = item
        window = window.squeeze()
        x,h_new = model(window,h)
        h = h_new.data
        model.zero_grad()     
        loss = criterion(x,target.T.squeeze())
        loss.backward()
        optimizer.step()
        if i%500 == 0 and epoch%2 == 0:
            print(f"Epoch {epoch}, item {i}, loss {loss.item()}")
# Out:
# /Users/faith/Library/Caches/pypoetry/virtualenvs/tsad-2yVHY76I-py3.10/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([33])) that is different to the input size (torch.Size([33, 33])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 0, item 0, loss 830499.4375
# Epoch 0, item 500, loss 76519944.0
# Epoch 2, item 0, loss 684008.5
# Epoch 2, item 500, loss 75735832.0
# Epoch 4, item 0, loss 576307.0
# Epoch 4, item 500, loss 75026616.0
# Epoch 6, item 0, loss 487121.40625
# Epoch 6, item 500, loss 74338424.0
# Epoch 8, item 0, loss 411479.5625
# Epoch 8, item 500, loss 73664376.0
# Epoch 10, item 0, loss 347608.71875
# Epoch 10, item 500, loss 73002696.0
# Epoch 12, item 0, loss 294988.8125
# Epoch 12, item 500, loss 72352920.0
# Epoch 14, item 0, loss 253462.28125
# Epoch 14, item 500, loss 71714928.0
# Epoch 16, item 0, loss 222868.796875
# Epoch 16, item 500, loss 71088504.0
# Epoch 18, item 0, loss 202991.484375
# Epoch 18, item 500, loss 70473448.0
# Epoch 20, item 0, loss 193507.984375
# Epoch 20, item 500, loss 69869408.0
# Epoch 22, item 0, loss 193907.90625
# Epoch 22, item 500, loss 69275776.0
# Epoch 24, item 0, loss 203307.453125
# Epoch 24, item 500, loss 68691568.0
# Epoch 26, item 0, loss 220235.984375
# Epoch 26, item 500, loss 68115224.0
# Epoch 28, item 0, loss 243054.46875
# Epoch 28, item 500, loss 67545248.0
# Epoch 30, item 0, loss 270853.8125
# Epoch 30, item 500, loss 66980892.0
# Epoch 32, item 0, loss 303286.28125
# Epoch 32, item 500, loss 66421776.0
# Epoch 34, item 0, loss 339944.375
# Epoch 34, item 500, loss 65867368.0
# Epoch 36, item 0, loss 380146.90625
# Epoch 36, item 500, loss 65316808.0
# Epoch 38, item 0, loss 423096.59375
# Epoch 38, item 500, loss 64769456.0
# Epoch 40, item 0, loss 468366.21875
# Epoch 40, item 500, loss 64225128.0
# Epoch 42, item 0, loss 515871.5
# Epoch 42, item 500, loss 63683824.0
# Epoch 44, item 0, loss 565599.25
# Epoch 44, item 500, loss 63145540.0
# Epoch 46, item 0, loss 617541.5625
# Epoch 46, item 500, loss 62610284.0
# Epoch 48, item 0, loss 671692.6875
# Epoch 48, item 500, loss 62078044.0
# Epoch 50, item 0, loss 728037.8125
# Epoch 50, item 500, loss 61548820.0
# Epoch 52, item 0, loss 786567.0625
# Epoch 52, item 500, loss 61022616.0
# Epoch 54, item 0, loss 847271.375
# Epoch 54, item 500, loss 60499416.0
# Epoch 56, item 0, loss 910137.125
# Epoch 56, item 500, loss 59979248.0
# Epoch 58, item 0, loss 975156.625
# Epoch 58, item 500, loss 59462064.0
# Epoch 60, item 0, loss 1042317.5
# Epoch 60, item 500, loss 58947896.0
# Epoch 62, item 0, loss 1111613.625
# Epoch 62, item 500, loss 58436724.0
# Epoch 64, item 0, loss 1183029.375
# Epoch 64, item 500, loss 57928528.0
# Epoch 66, item 0, loss 1256552.125
# Epoch 66, item 500, loss 57423348.0
# Epoch 68, item 0, loss 1332172.625
# Epoch 68, item 500, loss 56921184.0
# Epoch 70, item 0, loss 1409876.625
# Epoch 70, item 500, loss 56421976.0
# Epoch 72, item 0, loss 1489660.25
# Epoch 72, item 500, loss 55925756.0
# Epoch 74, item 0, loss 1571507.375
# Epoch 74, item 500, loss 55432528.0
# Epoch 76, item 0, loss 1655407.5
# Epoch 76, item 500, loss 54942252.0
# Epoch 78, item 0, loss 1741346.5
# Epoch 78, item 500, loss 54454964.0
# Epoch 80, item 0, loss 1829310.25
# Epoch 80, item 500, loss 53970660.0
# Epoch 82, item 0, loss 1919294.875
# Epoch 82, item 500, loss 53489300.0
# Epoch 84, item 0, loss 2011282.0
# Epoch 84, item 500, loss 53010920.0
# Epoch 86, item 0, loss 2105262.25
# Epoch 86, item 500, loss 52535480.0
# Epoch 88, item 0, loss 2201218.75
# Epoch 88, item 500, loss 52063028.0
# Epoch 90, item 0, loss 2299143.25
# Epoch 90, item 500, loss 51593500.0
# Epoch 92, item 0, loss 2399021.0
# Epoch 92, item 500, loss 51126920.0
# Epoch 94, item 0, loss 2500843.25
# Epoch 94, item 500, loss 50663292.0
# Epoch 96, item 0, loss 2604591.75
# Epoch 96, item 500, loss 50202576.0
# Epoch 98, item 0, loss 2710254.75
# Epoch 98, item 500, loss 49744836.0
# Epoch 100, item 0, loss 2817819.75
# Epoch 100, item 500, loss 49289988.0
# Epoch 102, item 0, loss 2927279.5
# Epoch 102, item 500, loss 48838092.0
# Epoch 104, item 0, loss 3038617.0
# Epoch 104, item 500, loss 48389092.0
# Epoch 106, item 0, loss 3151805.0
# Epoch 106, item 500, loss 47943044.0
# Epoch 108, item 0, loss 3266850.0
# Epoch 108, item 500, loss 47499896.0
# Epoch 110, item 0, loss 3383719.75
# Epoch 110, item 500, loss 47059656.0
# Epoch 112, item 0, loss 3502417.25
# Epoch 112, item 500, loss 46622340.0
# Epoch 114, item 0, loss 3622925.5
# Epoch 114, item 500, loss 46187864.0
# Epoch 116, item 0, loss 3745217.0
# Epoch 116, item 500, loss 45756356.0
# Epoch 118, item 0, loss 3869296.25
# Epoch 118, item 500, loss 45327692.0
# Epoch 120, item 0, loss 3995137.0
# Epoch 120, item 500, loss 44901904.0
# Epoch 122, item 0, loss 4122720.75
# Epoch 122, item 500, loss 44479052.0
# Epoch 124, item 0, loss 4252048.5
# Epoch 124, item 500, loss 44059024.0
# Epoch 126, item 0, loss 4383097.0
# Epoch 126, item 500, loss 43641856.0
# Epoch 128, item 0, loss 4515844.0
# Epoch 128, item 500, loss 43227580.0
# Epoch 130, item 0, loss 4650284.0
# Epoch 130, item 500, loss 42816168.0
# Epoch 132, item 0, loss 4786400.5
# Epoch 132, item 500, loss 42407596.0
# Epoch 134, item 0, loss 4924183.5
# Epoch 134, item 500, loss 42001844.0
# Epoch 136, item 0, loss 5063605.5
# Epoch 136, item 500, loss 41598976.0
# Epoch 138, item 0, loss 5204649.0
# Epoch 138, item 500, loss 41198952.0
# Epoch 140, item 0, loss 5347315.0
# Epoch 140, item 500, loss 40801736.0
# Epoch 142, item 0, loss 5491581.5
# Epoch 142, item 500, loss 40407336.0
# Epoch 144, item 0, loss 5637421.5
# Epoch 144, item 500, loss 40015780.0
# Epoch 146, item 0, loss 5784828.0
# Epoch 146, item 500, loss 39627020.0
# Epoch 148, item 0, loss 5933784.0
# Epoch 148, item 500, loss 39241080.0
# Epoch 150, item 0, loss 6084270.5
# Epoch 150, item 500, loss 38857952.0
# Epoch 152, item 0, loss 6236282.5
# Epoch 152, item 500, loss 38477604.0
# Epoch 154, item 0, loss 6389788.0
# Epoch 154, item 500, loss 38100044.0
# Epoch 156, item 0, loss 6544772.0
# Epoch 156, item 500, loss 37725308.0
# Epoch 158, item 0, loss 6701227.0
# Epoch 158, item 500, loss 37353312.0
# Epoch 160, item 0, loss 6859131.5
# Epoch 160, item 500, loss 36984060.0
# Epoch 162, item 0, loss 7018487.0
# Epoch 162, item 500, loss 36617572.0
# Epoch 164, item 0, loss 7179252.0
# Epoch 164, item 500, loss 36253896.0
# Epoch 166, item 0, loss 7341395.0
# Epoch 166, item 500, loss 35892956.0
# Epoch 168, item 0, loss 7504930.5
# Epoch 168, item 500, loss 35534752.0
# Epoch 170, item 0, loss 7669838.0
# Epoch 170, item 500, loss 35179244.0
# Epoch 172, item 0, loss 7836089.0
# Epoch 172, item 500, loss 34826472.0
# Epoch 174, item 0, loss 8003678.0
# Epoch 174, item 500, loss 34476448.0
# Epoch 176, item 0, loss 8172567.5
# Epoch 176, item 500, loss 34129132.0
# Epoch 178, item 0, loss 8342741.5
# Epoch 178, item 500, loss 33784536.0
# Epoch 180, item 0, loss 8514193.0
# Epoch 180, item 500, loss 33442648.0
# Epoch 182, item 0, loss 8686906.0
# Epoch 182, item 500, loss 33103444.0
# Epoch 184, item 0, loss 8860847.0
# Epoch 184, item 500, loss 32766916.0
# Epoch 186, item 0, loss 9036027.0
# Epoch 186, item 500, loss 32433030.0
# Epoch 188, item 0, loss 9212384.0
# Epoch 188, item 500, loss 32101910.0
# Epoch 190, item 0, loss 9389960.0
# Epoch 190, item 500, loss 31773326.0
# Epoch 192, item 0, loss 9568710.0
# Epoch 192, item 500, loss 31447444.0
# Epoch 194, item 0, loss 9748571.0
# Epoch 194, item 500, loss 31124232.0
# Epoch 196, item 0, loss 9929550.0
# Epoch 196, item 500, loss 30803642.0
# Epoch 198, item 0, loss 10111667.0
# Epoch 198, item 500, loss 30485666.0

# %%
PATH = "gat_model.pt"
torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            }, PATH)

# %% [markdown]
# # 4. Eval

# %%
test_windows = reshape_tensor(test,time_window)[:-1]
train_targets = get_targets(test,time_window)
prev_h = h
# test_dfs, test_min
test_windows.shape
# Out:
# torch.Size([863, 100, 33])

# %%
model.eval()
h = prev_h #model.init_hidden(1)
pred = None
for window in test_windows:
    x,h = model(window,h)
    if pred is None:
        pred = x.detach().numpy().reshape(-1)
    else:
        pred = np.vstack((pred,x.detach().numpy().reshape(-1)))

# %%
import matplotlib.pyplot as plt

for i in range(k):
    plt.plot(train_targets[1:,i])
    plt.plot(pred[1:,i])
    plt.show()
